# %% [markdown]
# ## Introducción a Python <br>
# Python es un lenguaje de **Programación** de alto nivel, enfocado en la inteligencia artificial.<br>
# Tmabién me permite generar aplicaciones de escritorio, web, moviles con programación orientada a objetos.<br>
# **Programador** Elvis Pachacama

# %%
# Aquí se escribe un comentario de una sola linea
print("Hola esto es un mensaje")
# Out:
# Hola esto es un mensaje

# %%
print("Elvis Pachacama")
# Out:
# Elvis Pachacama
